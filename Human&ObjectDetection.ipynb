# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilpoola07/Machine-Learning-Projects/blob/main/Human%26ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python matplotlib
# Out:
# ...
#   Using cached ultralytics-8.3.243-py3-none-any.whl.metadata (37 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.0 MB/s eta 0:00:00
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#upload files to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-230433f2-d87a-45a3-997e-429c6f366137" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-230433f2-d87a-45a3-997e-429c6f366137">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read the image with cv2
image_path = list(uploaded.keys())[0]
img = cv2.imread(image_path)
#convert bgr to rgb for display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#display the image
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
#perform object detection
model = YOLO('yolov8n.pt') # Load a pretrained YOLOv8n model
results = model(img)
# Out:
# 0: 416x640 1 person, 1 laptop, 105.9ms
# Speed: 4.5ms preprocess, 105.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)

# %%
#draw bounding boxes
annotated_image = results[0].plot()

#display the annoated image
plt.figure(figsize=(10, 10))
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
